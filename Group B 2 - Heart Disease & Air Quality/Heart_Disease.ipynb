# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random as rd
import sklearn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heart.csv")

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0      52    1   0       125   212    0        1      168      0      1.0  \
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope
# 0   52    1   0       125   212    0        1      168      0      1.0      2  \
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.dropna()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0      52    1   0       125   212    0        1      168      0      1.0  \
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0     52    1   0       125   212    0        1      168      0      1.0  \
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
df.shape
# Out:
# (302, 14)

# %%
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1
df = df[(df['age'] >= Q1 - 1.5 * IQR) & (df['age'] <= Q3 + 1.5 * IQR)]

# %%
Q1
# Out:
# 48.0

# %%
Q3
# Out:
# 61.0

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0     52    1   0       125   212    0        1      168      0      1.0  \
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
Q1 = df['chol'].quantile(0.25)
Q3 = df['chol'].quantile(0.75)
IQR = Q3 - Q1
df = df[(df['chol'] >= Q1 - 1.5 * IQR) & (df['chol'] <= Q3 + 1.5 * IQR)]

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0     52    1   0       125   212    0        1      168      0      1.0  \
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
df['ca'].unique()
# Out:
# array([2, 0, 1, 3, 4])

# %%
df.ca.value_counts()
# Out:
# ca
# 0    173
# 1     64
# 2     37
# 3     19
# 4      4
# Name: count, dtype: int64

# %%
from sklearn import linear_model,metrics

# %%
x=df[["age"]]
y=df[["thal"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
len(x_train)
# Out:
# 237

# %%
len(x_test)
# Out:
# 60

# %%
reg=linear_model.LinearRegression()

# %%
x_train
# Out:
#      age
# 212   50
# 128   52
# 337   54
# 333   54
# 41    54
# ..   ...
# 301   51
# 449   52
# 78    52
# 373   58
# 39    57
#
# [237 rows x 1 columns]

# %%
model=reg.fit(x_train,y_train)

# %%
r_sq=reg.score(x_train,y_train)

# %%
print("determination coefficient:",r_sq)
# Out:
# determination coefficient: 0.006466663940629003

# %%
print ("intercept:",model.intercept_)
# Out:
# intercept: [2.03975384]

# %%
model.intercept_
# Out:
# array([2.03975384])

# %%
model.coef_
# Out:
# array([[0.00532193]])

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([[2.24730896],
#        [2.34842555],
#        [2.33245978],
#        [2.316494  ],
#        [2.37503519],
#        [2.40164482],
#        [2.39632289],
#        [2.23666511],
#        [2.3377817 ],
#        [2.24730896],
#        [2.34842555],
#        [2.28988437],
#        [2.26859666],
#        [2.41761059],
#        [2.34310363],
#        [2.34842555],
#        [2.316494  ],
#        [2.25795281],
#        [2.27391859],
#        [2.30585015],
#        [2.35906941],
#        [2.22069933],
#        [2.32713785],
#        [2.34842555],
#        [2.36439133],
#        [2.36971326],
#        [2.32713785],
#        [2.35374748],
#        [2.22602125],
#        [2.35906941],
#        [2.34842555],
#        [2.31117207],
#        [2.38567904],
#        [2.316494  ],
#        [2.34310363],
#        [2.30052822],
#        [2.34310363],
#        [2.34310363],
#        [2.34310363],
#        [2.26859666],
#        [2.36971326],
#        [2.25795281],
#        [2.27391859],
# ...

# %%
x_train2=x_train.to_numpy()

# %%
plt.scatter(x_train2,y_train,color ="black")
plt.plot(x_train2,reg.predict(x_train2),color="blue",linewidth=3)
plt.title("age vs thal")
plt.xlabel("age")
plt.ylabel("thal")
plt.show()
# Out:
# /home/suhas/.local/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x_test2=x_test.to_numpy()

# %%
plt.scatter(x_test2,y_test,color ="red")
plt.plot(x_test2,reg.predict(x_test2),color="black",linewidth=3)
plt.title("age vs thal")
plt.xlabel("age")
plt.ylabel("slope")
plt.show()
# Out:
# /home/suhas/.local/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
